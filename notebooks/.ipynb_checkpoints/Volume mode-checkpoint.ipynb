# %%
#coloca o path raiz do projeto
working_path = "/home/thierry/Documents/thierry/"

# %%
import pandas as pd

# %%
data = pd.read_csv("/home/thierry/Documents/thierry/data/0b2b9de31dfcb837.csv")
data['index'] = range(0, len(data))

# %%
data30s = data.iloc[ 0::2 , [14,16]]
data60s = data.iloc[ 0::4 , [14,16]]
data120s = data.iloc[ 0::8 , [14,16]]

# %%
data
# Out:
#        latitude  longitude    altitude  accuracy provider  speed  \
# 0     -7.255347 -35.911039    0.000000    23.476    fused    0.0
# 1     -7.255234 -35.910971    0.000000    37.265    fused    0.0
# 2     -7.255234 -35.910971    0.000000    42.025    fused    0.0
# 3     -7.257795 -35.910951    0.000000   699.999    fused    0.0
# 4     -7.255307 -35.911276  510.600006    39.560    fused    0.0
# ...         ...        ...         ...       ...      ...    ...
# 14839 -7.250728 -35.917420    0.000000  2099.999    fused    0.0
# 14840 -7.250728 -35.917420    0.000000  2099.999    fused    0.0
# 14841 -7.250728 -35.917420    0.000000  2099.999    fused    0.0
# 14842 -7.255205 -35.912985    0.000000    72.900    fused    0.0
# 14843 -7.255205 -35.912985    0.000000    72.900    fused    0.0
#
#            timestamp                                date  temperature  \
# 0      1566781277839  Sun Aug 25 22:01:19 GMT-03:00 2019          0.0
# 1      1566781308952  Sun Aug 25 22:01:49 GMT-03:00 2019          0.0
# 2      1566781325109  Sun Aug 25 22:02:05 GMT-03:00 2019          0.0
# 3      1566781355015  Sun Aug 25 22:02:35 GMT-03:00 2019          0.0
# 4      1566781370091  Sun Aug 25 22:02:50 GMT-03:00 2019          0.0
# ...              ...                                 ...          ...
# 14839  1569022034874  Fri Sep 20 20:27:14 GMT-03:00 2019          0.0
# 14840  1569022206126  Fri Sep 20 20:30:06 GMT-03:00 2019          0.0
# 14841  1569022340997  Fri Sep 20 20:32:21 GMT-03:00 2019          0.0
# 14842  1568786125970  Wed Sep 18 02:55:26 GMT-03:00 2019          0.0
# 14843  1568786313330  Wed Sep 18 02:58:33 GMT-03:00 2019          0.0
#
#        humidity  light  proximity  pressure  screen   audio  voluntary_id  \
# 0           0.0    0.0   5.000305       0.0   False  Normal            12
# 1           0.0    0.0   5.000305       0.0    True  Normal            12
# 2           0.0    0.0   5.000305       0.0    True  Normal            12
# 3           0.0    0.0   5.000305       0.0    True  Normal            12
# 4           0.0    0.0   5.000305       0.0    True  Normal            12
# ...         ...    ...        ...       ...     ...     ...           ...
# 14839       0.0   25.0   5.000305       0.0   False  Normal            12
# 14840       0.0   25.0   5.000305       0.0   False  Normal            12
# 14841       0.0   25.0   5.000305       0.0   False  Normal            12
# 14842       0.0   39.0   5.000305       0.0   False  Normal            12
# 14843       0.0   39.0   5.000305       0.0   False  Normal            12
#
#        index
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 14839  14839
# 14840  14840
# 14841  14841
# 14842  14842
# 14843  14843
#
# [14844 rows x 17 columns]

# %%
def find_audio_mode(df, mode):
    usage = 0
    for i in df.index.values:
        if(df['audio'][i]==mode):
            usage+=1
        
    return usage

# %%
n_vibrate = find_audio_mode(data30s, 'Vibrate')
n_silent = find_audio_mode(data30s, 'Silent')
n_normal = find_audio_mode(data30s, 'Normal')

# %%
print(n_vibrate)
print(n_silent)
print(n_normal)
# Out:
# 0
# 1
# 7421

# %%
def find_all_audio_mode(df,grouping,mode):
    usage = 0
    for i in range(0,len(df),grouping):
        usage += checkMode(df[i:(i+grouping)],mode)
    return usage

# %%
def checkMode(df,mode):
    result = False
    for i in df.index.values:
        result = result or (df['audio'][i] == mode)
    return 1 if result else 0

# %%
print("Porcentagem mode normal 30s",find_audio_mode(data30s,'Normal')/find_all_audio_mode(data,2,'Normal'))
print("Porcentagem mode normal 60s",find_audio_mode(data60s,'Normal')/find_all_audio_mode(data,4,'Normal'))
print("Porcentagem mode normal 120s",find_audio_mode(data120s,'Normal')/find_all_audio_mode(data,8,'Normal'))
# Out:
# Porcentagem mode normal 30s 0.9998652654271086
# Porcentagem mode normal 60s 1.0
# Porcentagem mode normal 120s 1.0

# %%
print("Porcentagem mode silent 30s",find_audio_mode(data30s,'Silent')/find_all_audio_mode(data,2,'Silent'))
print("Porcentagem mode silent 60s",find_audio_mode(data60s,'Silent')/find_all_audio_mode(data,4,'Silent'))
print("Porcentagem mode silent 120s",find_audio_mode(data120s,'Silent')/find_all_audio_mode(data,8,'Silent'))
# Out:
# Porcentagem mode silent 30s 1.0
# Porcentagem mode silent 60s 0.0
# Porcentagem mode silent 120s 0.0

# %%
if(find_all_audio_mode(data,2,'Vibrate')!=0):
    print("Porcentagem mode vibrate 30s",find_audio_mode(data30s,'Vibrate')/find_all_audio_mode(data,2,'Vibrate'))
if(find_all_audio_mode(data,4,'Vibrate')!=0):    
    print("Porcentagem mode vibrate 60s",find_audio_mode(data60s,'Vibrate')/find_all_audio_mode(data,4,'Vibrate'))
if(find_all_audio_mode(data,8,'Vibrate')!=0):    
    print("Porcentagem mode vibrate 120s",find_audio_mode(data120s,'Vibrate')/find_all_audio_mode(data,8,'Vibrate'))
